# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy as sc
import scipy.optimize as sco
import scipy.constants as c
from scipy.optimize import curve_fit as cf
import pandas as pd

# %%
def getData(M,I):
            
    mass,intensity=[],[]
    for i in M:
        try:
            mass.append(int(i.replace(',00','')))
        except ValueError:
            continue

    for i in I:
        try:
            value=float(i.replace(',','.'))
            if value>.005:
                continue
            intensity.append(value)
        except ValueError:
            continue  
    
    return mass,intensity

# %%
elements=[2,18,28,32,40,44]
elementNames=["$H_2$","$H_2O$","$N_2$","$O_2$","Ar","$CO_2$"]
ticks=[0,10,25,35,50]
ticklabels=["0","10","25","35","50"]

data=[]
data.append( pd.read_csv("20180307_JonasLehnenGuntherTuerk/20180308 101236 Faraday Bargraph Cycles AfterBaking.asc",
                         delimiter="\t",skiprows=0 ))

for entry in data:
    M= entry.values[:,0]
    I= entry.values[:,1]

mass,intensity=getData(M,I)

fig,ax=plt.subplots(dpi=144)

i1=intensity[:50]
i2=intensity[50:100]
i3=intensity[100:150]

meanI1= [sum(x)/3 for x in zip(i1,i2,i3)]

barlist=ax.bar(mass[:50],meanI1,log=True)
for i in elements:
    barlist[i-1].set_facecolor("r")
    
ax.set(ylim=[1e-14,2e-11], xlabel="Atomic Mass [amu]", ylabeL="Mean Intensity / Ion Current [A]",
      title="Mass Spectrometer After Baking")
plt.xticks(elements+ticks,elementNames+ticklabels)
fig.savefig("Plots/MSafter")

# %%
data=[]
data.append( pd.read_csv("20180307_JonasLehnenGuntherTuerk/20180307 141332 Faraday Bargraph Cycles 2.asc",delimiter="\t"))
for entry in data:
    M= entry.values[:,0]
    I= entry.values[:,1]

mass,intensity=getData(M,I)
i1=intensity[:50]
i2=intensity[50:100]

#2 Zyklen in 2, einer in 3 ( amu 50 fehlt...)
data.append( pd.read_csv("20180307_JonasLehnenGuntherTuerk/20180307 144721 Faraday Bargraph Cycles 3.asc",delimiter="\t"))
for entry in data:
    M= entry.values[:,0]
    I= entry.values[:,1]

_,intensity=getData(M,I)
i3=intensity[:49]
i3.append((i1[49]+i2[49])/2)

meanI2= [sum(x)/3 for x in zip(i1,i2,i3)]
fig,ax=plt.subplots(dpi=144)
barlist=ax.bar(mass[:50],meanI2,log=True)
ax.set(ylim=[1e-15,3e-10], xlabel="Atomic Mass [amu]", ylabeL="Mean Intensity / Ion Current [A]",
      title="Mass Spectrometer Before Baking")

for i in elements:
    barlist[i-1].set_facecolor("r")
plt.xticks(elements+ticks,elementNames+ticklabels)

fig.savefig("Plots/MSbefore")

# Warum sind in den Daten negative Currents? Hier erkennbar durch die "exakt" Nullstellen.

# %%
from matplotlib.lines import Line2D

shift=.3
massShift=[x for x in mass[:50]]
massIndex=[x-shift for x in mass[:50]]
cBefore,cAfter=["navy","m"],["c","tomato"]

custom_lines = [Line2D([0], [0], color=cBefore[0], lw=4, marker="o",mfc=cBefore[1],ms=10),
                Line2D([0], [0], color=cAfter[0 ], lw=4, marker="o",mfc=cAfter[1],ms=10)]


fig,ax=plt.subplots(dpi=144)
barlist1=ax.bar(massIndex,meanI2, width=shift ,log=True,color=cBefore[0])
barlist2=ax.bar(massShift,meanI1, width=shift ,log=True,color=cAfter[0])
ax.set(ylim=[1e-15,3e-10], xlabel="Atomic Mass [amu]", ylabeL="Mean Intensity / Ion Current [A]",
      title="Mass Spectrometer Comparison: Before - After")


for i in elements:
    barlist1[i-1].set(facecolor=cBefore[1])
    barlist2[i-1].set_facecolor(cAfter[1])
newTicks=[x-shift/2 for x in elements+ticks]
plt.xticks(newTicks,elementNames+ticklabels)
ax.legend(custom_lines, ['Before Baking', 'After Baking'])

fig.savefig("Plots/BeforeAfter.png")
